# %%
import numpy as np

# Pandas, conventionally imported as pd
import pandas as pd

import scipy as sp

# Plotting modules and settings.
import matplotlib.pyplot as plt
import seaborn as sns
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728',
          '#9467bd', '#8c564b', '#e377c2', '#7f7f7f',
          '#bcbd22', '#17becf']
sns.set(style='whitegrid', palette=colors, rc={'axes.labelsize': 16})

# The following is specific Jupyter notebooks
# %matplotlib inline
# %config InlineBackend.figure_formats = {'png', 'retina'}


# Slice out x and y values
data = pd.read_csv('/Users/ShuaiWang/Desktop/Shan_Lab/Ribo_seq/Data_analysis/SecA_enrichment_BrianRPM.csv', comment='#')
data
# Out:
#       gene              localization  SRPenrichment_RPM  \
# 0     fhuA      OutermembraneProtein               0.84
# 1      flu      OutermembraneProtein               0.91
# 2     acrA               Lipoprotein               0.74
# 3     btuB      OutermembraneProtein               1.06
# 4     yfdI   IntegralMembraneProtein               6.82
# 5     dcuA   IntegralMembraneProtein               6.89
# 6     nupC   IntegralMembraneProtein               3.44
# 7     nupG   IntegralMembraneProtein               4.17
# 8     sdaC   IntegralMembraneProtein               4.91
# 9     lldP   IntegralMembraneProtein               7.49
# 10    yeeF   IntegralMembraneProtein               3.33
# 11    yjiY   IntegralMembraneProtein               2.22
# 12     ais               Periplasmic               3.00
# 13    yedR   IntegralMembraneProtein               5.90
# 14    fxsA   IntegralMembraneProtein               2.37
# 15    nagE   IntegralMembraneProtein               1.54
# ...

# %%
import numpy as np

# Pandas, conventionally imported as pd
import pandas as pd

import scipy as sp

# Plotting modules and settings.
import matplotlib.pyplot as plt
import seaborn as sns
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728',
          '#9467bd', '#8c564b', '#e377c2', '#7f7f7f',
          '#bcbd22', '#17becf']
sns.set(style='whitegrid', palette=colors, rc={'axes.labelsize': 16})

# The following is specific Jupyter notebooks
# %matplotlib inline
# %config InlineBackend.figure_formats = {'png', 'retina'}


# Slice out x and y values
data = pd.read_csv('/Users/ShuaiWang/Desktop/Shan_Lab/Ribo_seq/Data_analysis/SecA_enrichment_BrianRPM.csv', comment='#')
sns.set_style("whitegrid")
fig, ax = plt.subplots(figsize=(15, 20))
#plt.xscale('log', basex=2)
ax = sns.violinplot(x=data["localization"],y=data["5mM_EDC enrich"],data=data, width=0.5, scale="width")
sns.violinplot

#Add a title
plt.title('10Mread_5mM_EDC_enrichment', fontsize=20, loc='center')
# Out:
# Text(0.5,1,'10Mread_5mM_EDC_enrichment')

# %%
import numpy as np

# Pandas, conventionally imported as pd
import pandas as pd

import scipy as sp

# Plotting modules and settings.
import matplotlib.pyplot as plt
import seaborn as sns
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728',
          '#9467bd', '#8c564b', '#e377c2', '#7f7f7f',
          '#bcbd22', '#17becf']
sns.set(style='whitegrid', palette=colors, rc={'axes.labelsize': 16})

# The following is specific Jupyter notebooks
# %matplotlib inline
# %config InlineBackend.figure_formats = {'png', 'retina'}


# Slice out x and y values
data = pd.read_csv('/Users/ShuaiWang/Desktop/Shan_Lab/Ribo_seq/Data_analysis/SecA_enrichment_BrianRPM.csv', comment='#')
sns.set_style("whitegrid")
fig, ax = plt.subplots(figsize=(15, 20))
plt.xscale('log', basex=2)
ax = sns.violinplot(y=data["localization"],x=data["all_data_enrichment"],data=data,width=1, inner="stick")
sns.violinplot

#ax.set_xlim(0, 8)

#Add a title
plt.title('all_data_enrichment', fontsize=20, loc='center')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'all_data_enrichment'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-449d171c052e> in <module>()
# ...

# %%
import numpy as np

# Pandas, conventionally imported as pd
import pandas as pd

import scipy as sp

# Plotting modules and settings.
import matplotlib.pyplot as plt
import seaborn as sns
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728',
          '#9467bd', '#8c564b', '#e377c2', '#7f7f7f',
          '#bcbd22', '#17becf']
sns.set(style='whitegrid', palette=colors, rc={'axes.labelsize': 16})

# The following is specific Jupyter notebooks
# %matplotlib inline
# %config InlineBackend.figure_formats = {'png', 'retina'}


# Slice out x and y values
data = pd.read_csv('/Users/ShuaiWang/Desktop/Shan_Lab/Ribo_seq/Data_analysis/SecA_enrichment_BrianRPM.csv', comment='#')
sns.set_style("whitegrid")
fig, ax = plt.subplots(figsize=(15, 7.5))
#plt.xscale('log', basex=2)
ax = sns.violinplot(x=data["localization"],y=data["SRPenrichment_RPM"],data=data,width=0.5,scale="width")
sns.violinplot

#Add a title
plt.title('SRPenrichment_RPM', fontsize=20, loc='center')
# Out:
# Text(0.5,1,'SRPenrichment_RPM')

# %%
import numpy as np

# Pandas, conventionally imported as pd
import pandas as pd

import scipy as sp

# Plotting modules and settings.
import matplotlib.pyplot as plt
import seaborn as sns
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728',
          '#9467bd', '#8c564b', '#e377c2', '#7f7f7f',
          '#bcbd22', '#17becf']
sns.set(style='whitegrid', palette=colors, rc={'axes.labelsize': 16})

# The following is specific Jupyter notebooks
# %matplotlib inline
# %config InlineBackend.figure_formats = {'png', 'retina'}


# Slice out x and y values
data = pd.read_csv('/Users/ShuaiWang/Desktop/Shan_Lab/Ribo_seq/Data_analysis/SecA_enrichment_BrianRPM.csv', comment='#')
sns.set_style("whitegrid")
fig, ax = plt.subplots(figsize=(15, 7.5))
#plt.xscale('log', basex=2)
ax = sns.violinplot(x=data["localization"],y=data["SRPenrichment_RPM_log2"],data=data,width=0.5,scale="width")
sns.violinplot

#Add a title
plt.title('SRPenrichment_RPM', fontsize=20, loc='center')

plt.savefig('/Users/ShuaiWang/Desktop/Shan_Lab/Ribo_seq/Data_analysis/Shuai_Plot/SRP_enrichment_violin.pdf')

# %%
import numpy as np

# Pandas, conventionally imported as pd
import pandas as pd

import scipy as sp

# Plotting modules and settings.
import matplotlib.pyplot as plt
import seaborn as sns
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728',
          '#9467bd', '#8c564b', '#e377c2', '#7f7f7f',
          '#bcbd22', '#17becf']
sns.set(style='whitegrid', palette=colors, rc={'axes.labelsize': 16})

# The following is specific Jupyter notebooks
# %matplotlib inline
# %config InlineBackend.figure_formats = {'png', 'retina'}


# Slice out x and y values
data = pd.read_csv('/Users/ShuaiWang/Desktop/Shan_Lab/Ribo_seq/Data_analysis/SecA_enrichment_BrianRPM.csv', comment='#')
sns.set_style("whitegrid")
fig, ax = plt.subplots(figsize=(15, 7.5))
#plt.xscale('log', basex=2)
ax = sns.violinplot(x=data["localization"],y=data["60M_5mM_EDC_enrichment_log2"],data=data,width=1)
sns.violinplot

#Add a title
plt.title('60M_5mM_EDC_enrichment', fontsize=20, loc='center')

plt.savefig('/Users/ShuaiWang/Desktop/Shan_Lab/Ribo_seq/Data_analysis/Shuai_Plot/SecA_60M_5mMEDC_enrich_violin.pdf')
