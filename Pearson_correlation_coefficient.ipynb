# %%
import numpy as np

# Pandas, conventionally imported as pd
import pandas as pd

import scipy as sp

# Plotting modules and settings.
import matplotlib.pyplot as plt
import seaborn as sns
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728',
          '#9467bd', '#8c564b', '#e377c2', '#7f7f7f',
          '#bcbd22', '#17becf']
sns.set(style='whitegrid', palette=colors, rc={'axes.labelsize': 16})

# The following is specific Jupyter notebooks
# %matplotlib inline
# %config InlineBackend.figure_formats = {'png', 'retina'}


# Slice out x and y values
data = pd.read_csv('/Users/ShuaiWang/Desktop/Shan_Lab/Ribo_seq/Data_analysis/SecA_BrianRPM_043018.csv', comment='#')

integralmem_x = data.loc[(data['localization'] == 'IntegralMembraneProtein'),'5mM_EDC enrich']
integralmem_y = data.loc[(data['localization'] == 'IntegralMembraneProtein'),'10mM_EDC_enrich']

cyto_x = data.loc[(data['localization'] == 'Cytoplasmic'),'5mM_EDC enrich']
cyto_y = data.loc[(data['localization'] == 'Cytoplasmic'),'10mM_EDC_enrich']

peri_x = data.loc[(data['localization'] == 'Periplasmic'),'5mM_EDC enrich']
peri_y = data.loc[(data['localization'] == 'Periplasmic'),'10mM_EDC_enrich']

memanchor_x = data.loc[(data['localization'] == 'Membrane-anchored'),'5mM_EDC enrich']
memanchor_y = data.loc[(data['localization'] == 'Membrane-anchored'),'10mM_EDC_enrich']

memassoci_x = data.loc[(data['localization'] == 'Membraneassociated'),'5mM_EDC enrich']
memassoci_y = data.loc[(data['localization'] == 'Membraneassociated'),'10mM_EDC_enrich']

outermem_x = data.loc[(data['localization'] == 'OutermembraneProtein'),'5mM_EDC enrich']
outermem_y = data.loc[(data['localization'] == 'OutermembraneProtein'),'10mM_EDC_enrich']

outerlipo_x = data.loc[(data['localization'] == 'OutermembraneLipoprotein'),'5mM_EDC enrich']
outerlipo_y = data.loc[(data['localization'] == 'OutermembraneLipoprotein'),'10mM_EDC_enrich']

lipo_x = data.loc[(data['localization'] == 'Lipoprotein'),'5mM_EDC enrich']
lipo_y = data.loc[(data['localization'] == 'Lipoprotein'),'10mM_EDC_enrich']

extracel_x = data.loc[(data['localization'] == 'extracellular'),'5mM_EDC enrich']
extracel_y = data.loc[(data['localization'] == 'extracellular'),'10mM_EDC_enrich']

na_x = data.loc[(data['localization'] == '-'),'5mM_EDC enrich']
na_y = data.loc[(data['localization'] == '-'),'10mM_EDC_enrich']


# Make a plot with labeled axes, etc
fig, ax = plt.subplots(figsize=(15, 7.5))
ax.set_xlabel('5mM_EDC_enrichment')
ax.set_ylabel('10mM_EDC_enrichment')

plt.xscale('linear' )
plt.yscale('linear' )

#plt.autoscale

# Make nice y-limits
ax.set_ylim(0, 10)
ax.set_xlim(0, 10)
plt.gca().set_aspect('equal', adjustable='box')


# plot content
_ = ax.plot(integralmem_x, integralmem_y, marker='.', color=(1,0,0),linestyle='none', markersize=4)
_ = ax.plot(cyto_x, cyto_y, marker='.', color=(0,0,1),linestyle='none', markersize=4)
_ = ax.plot(peri_x, peri_y, marker='.', color=(0,0.6,0),linestyle='none', markersize=4)
_ = ax.plot(memanchor_x, memanchor_y, marker='.', color=(1,0,0),linestyle='none', markersize=4)
_ = ax.plot(memassoci_x, memassoci_y, marker='.', color=(1,0,0),linestyle='none', markersize=4)
_ = ax.plot(outermem_x, outermem_y, marker='.', color=(0,0.6,0),linestyle='none', markersize=4)
_ = ax.plot(outerlipo_x, outerlipo_y, marker='.', color=(0,0.6,0),linestyle='none', markersize=4)
#_ = ax.plot(lipo_x, lipo_y, marker='.', color=(1,1,1),linestyle='none')
#_ = ax.plot(extracel_x, extracel_y, marker='.', color=(1,1,1),linestyle='none')
#_ = ax.plot(na_x, na_y, marker='.', color=(1,1,1),linestyle='none')
#_ = ax.plot(markerline_x, markerline_x, marker='.', color=(0,0,0),linestyle='none')

plt.plot([0, 10], [0, 10], '-',linewidth=1, color=(0,0,0))
# Add a legend
plt.legend(('integralmembrane','cytosolic','periplasmic','membrane_anchor','membrane_associated','outermembrane','outerlipo','lipo','extracellular','NA'), loc='upper left');

#Add a title
plt.title('SecA_5mMvs10mM_EDC_enrichment', fontsize=20, loc='center')

#calculate pearson correlation coefficient
x = data.loc[:,'5mM_EDC enrich']
y = data.loc[:,'10mM_EDC_enrich']
print('pearson correlatin coefficient and p-value:')
print(sp.stats.pearsonr(x,y))

#plt.savefig('/Users/ShuaiWang/Desktop/Shan_Lab/Ribo_seq/Data_analysis/Shuai_Plot/xx.pdf')
# Out:
# pearson correlatin coefficient and p-value:
# (0.7476093630200121, 0.0)

# %%
import numpy as np

# Pandas, conventionally imported as pd
import pandas as pd

# Plotting modules and settings.
import matplotlib.pyplot as plt
import seaborn as sns
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728',
          '#9467bd', '#8c564b', '#e377c2', '#7f7f7f',
          '#bcbd22', '#17becf']
sns.set(style='whitegrid', palette=colors, rc={'axes.labelsize': 16})

# The following is specific Jupyter notebooks
# %matplotlib inline
# %config InlineBackend.figure_formats = {'png', 'retina'}


# Slice out x and y values
data = pd.read_csv('/Users/ShuaiWang/Desktop/Shan_Lab/Ribo_seq/Data_analysis/SecA_BrianRPM_043018.csv', comment='#')

integralmem_x = data.loc[(data['localization'] == 'IntegralMembraneProtein'),'5mM_EDC_input']
integralmem_y = data.loc[(data['localization'] == 'IntegralMembraneProtein'),'10mM_EDC_input']

cyto_x = data.loc[(data['localization'] == 'Cytoplasmic'),'5mM_EDC_input']
cyto_y = data.loc[(data['localization'] == 'Cytoplasmic'),'10mM_EDC_input']

peri_x = data.loc[(data['localization'] == 'Periplasmic'),'5mM_EDC_input']
peri_y = data.loc[(data['localization'] == 'Periplasmic'),'10mM_EDC_input']

memanchor_x = data.loc[(data['localization'] == 'Membrane-anchored'),'5mM_EDC_input']
memanchor_y = data.loc[(data['localization'] == 'Membrane-anchored'),'10mM_EDC_input']

memassoci_x = data.loc[(data['localization'] == 'Membraneassociated'),'5mM_EDC_input']
memassoci_y = data.loc[(data['localization'] == 'Membraneassociated'),'10mM_EDC_input']

outermem_x = data.loc[(data['localization'] == 'OutermembraneProtein'),'5mM_EDC_input']
outermem_y = data.loc[(data['localization'] == 'OutermembraneProtein'),'10mM_EDC_input']

outerlipo_x = data.loc[(data['localization'] == 'OutermembraneLipoprotein'),'5mM_EDC_input']
outerlipo_y = data.loc[(data['localization'] == 'OutermembraneLipoprotein'),'10mM_EDC_input']

lipo_x = data.loc[(data['localization'] == 'Lipoprotein'),'5mM_EDC_input']
lipo_y = data.loc[(data['localization'] == 'Lipoprotein'),'10mM_EDC_input']

extracel_x = data.loc[(data['localization'] == 'extracellular'),'5mM_EDC_input']
extracel_y = data.loc[(data['localization'] == 'extracellular'),'10mM_EDC_input']

na_x = data.loc[(data['localization'] == '-'),'5mM_EDC_input']
na_y = data.loc[(data['localization'] == '-'),'10mM_EDC_input']


# Make a plot with labeled axes, etc
fig, ax = plt.subplots(figsize=(15, 7.5))
ax.set_xlabel('5mM_EDC_input')
ax.set_ylabel('10mM_EDC_input')

plt.xscale('log')
plt.yscale('log')

# Make nice y-limits
ax.set_ylim(1, 1000000)
ax.set_xlim(1, 1000000)
plt.gca().set_aspect('equal', adjustable='box')


# plot content
_ = ax.plot(integralmem_x, integralmem_y, marker='.', color=(1,0,0),linestyle='none', markersize=4)
_ = ax.plot(cyto_x, cyto_y, marker='.', color=(0,0,1),linestyle='none', markersize=4)
_ = ax.plot(peri_x, peri_y, marker='.', color=(0,0.6,0),linestyle='none', markersize=4)
_ = ax.plot(memanchor_x, memanchor_y, marker='.', color=(1,0,0),linestyle='none', markersize=4)
_ = ax.plot(memassoci_x, memassoci_y, marker='.', color=(1,0,0),linestyle='none', markersize=4)
_ = ax.plot(outermem_x, outermem_y, marker='.', color=(0,0.6,0),linestyle='none', markersize=4)
_ = ax.plot(outerlipo_x, outerlipo_y, marker='.', color=(0,0.6,0),linestyle='none', markersize=4)
#_ = ax.plot(lipo_x, lipo_y, marker='.', color=(1,1,1),linestyle='none')
#_ = ax.plot(extracel_x, extracel_y, marker='.', color=(1,1,1),linestyle='none')
#_ = ax.plot(na_x, na_y, marker='.', color=(1,1,1),linestyle='none')
#_ = ax.plot(markerline_x, markerline_x, marker='.', color=(0,0,0),linestyle='none')

plt.plot([1, 1000000], [1, 1000000], '-',linewidth=1, color=(0,0,0))
# Add a legend
plt.legend(('integralmembrane','cytosolic','periplasmic','membrane_anchor','membrane_associated','outermembrane','outerlipo','lipo','extracellular','NA'), loc='upper left');

#Add a title
plt.title('SecA_5mMvs10mM_EDC_enrichment', fontsize=20, loc='center')

#calculate pearson correlation coefficient
x = data.loc[:,'5mM_EDC_input']
y = data.loc[:,'10mM_EDC_input']
print('pearson correlatin coefficient and p-value:')
print(sp.stats.pearsonr(x,y))
#plt.savefig('/Users/ShuaiWang/Desktop/Shan_Lab/Ribo_seq/Data_analysis/Shuai_Plot/xx.pdf')
# Out:
# pearson correlatin coefficient and p-value:
# (0.998654039396516, 0.0)

# %%
import numpy as np

# Pandas, conventionally imported as pd
import pandas as pd

# Plotting modules and settings.
import matplotlib.pyplot as plt
import seaborn as sns
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728',
          '#9467bd', '#8c564b', '#e377c2', '#7f7f7f',
          '#bcbd22', '#17becf']
sns.set(style='whitegrid', palette=colors, rc={'axes.labelsize': 16})

# The following is specific Jupyter notebooks
# %matplotlib inline
# %config InlineBackend.figure_formats = {'png', 'retina'}


# Slice out x and y values
data = pd.read_csv('/Users/ShuaiWang/Desktop/Shan_Lab/Ribo_seq/Data_analysis/SecA_BrianRPM_043018.csv', comment='#')

integralmem_x = data.loc[(data['localization'] == 'IntegralMembraneProtein'),'5mM_EDC_resin']
integralmem_y = data.loc[(data['localization'] == 'IntegralMembraneProtein'),'10mM_EDC_resin']

cyto_x = data.loc[(data['localization'] == 'Cytoplasmic'),'5mM_EDC_resin']
cyto_y = data.loc[(data['localization'] == 'Cytoplasmic'),'10mM_EDC_resin']

peri_x = data.loc[(data['localization'] == 'Periplasmic'),'5mM_EDC_resin']
peri_y = data.loc[(data['localization'] == 'Periplasmic'),'10mM_EDC_resin']

memanchor_x = data.loc[(data['localization'] == 'Membrane-anchored'),'5mM_EDC_resin']
memanchor_y = data.loc[(data['localization'] == 'Membrane-anchored'),'10mM_EDC_resin']

memassoci_x = data.loc[(data['localization'] == 'Membraneassociated'),'5mM_EDC_resin']
memassoci_y = data.loc[(data['localization'] == 'Membraneassociated'),'10mM_EDC_resin']

outermem_x = data.loc[(data['localization'] == 'OutermembraneProtein'),'5mM_EDC_resin']
outermem_y = data.loc[(data['localization'] == 'OutermembraneProtein'),'10mM_EDC_resin']

outerlipo_x = data.loc[(data['localization'] == 'OutermembraneLipoprotein'),'5mM_EDC_resin']
outerlipo_y = data.loc[(data['localization'] == 'OutermembraneLipoprotein'),'10mM_EDC_resin']

lipo_x = data.loc[(data['localization'] == 'Lipoprotein'),'5mM_EDC_resin']
lipo_y = data.loc[(data['localization'] == 'Lipoprotein'),'10mM_EDC_resin']

extracel_x = data.loc[(data['localization'] == 'extracellular'),'5mM_EDC_resin']
extracel_y = data.loc[(data['localization'] == 'extracellular'),'10mM_EDC_resin']

na_x = data.loc[(data['localization'] == '-'),'5mM_EDC_resin']
na_y = data.loc[(data['localization'] == '-'),'10mM_EDC_resin']


# Make a plot with labeled axes, etc
fig, ax = plt.subplots(figsize=(15, 7.5))
ax.set_xlabel('5mM_EDC_resin')
ax.set_ylabel('10mM_EDC_resin')

plt.xscale('log')
plt.yscale('log')

# Make nice y-limits
ax.set_ylim(1, 1000000)
ax.set_xlim(1, 1000000)
plt.gca().set_aspect('equal', adjustable='box')


# plot content
_ = ax.plot(integralmem_x, integralmem_y, marker='.', color=(1,0,0),linestyle='none', markersize=4)
_ = ax.plot(cyto_x, cyto_y, marker='.', color=(0,0,1),linestyle='none', markersize=4)
_ = ax.plot(peri_x, peri_y, marker='.', color=(0,0.6,0),linestyle='none', markersize=4)
_ = ax.plot(memanchor_x, memanchor_y, marker='.', color=(1,0,0),linestyle='none', markersize=4)
_ = ax.plot(memassoci_x, memassoci_y, marker='.', color=(1,0,0),linestyle='none', markersize=4)
_ = ax.plot(outermem_x, outermem_y, marker='.', color=(0,0.6,0),linestyle='none', markersize=4)
_ = ax.plot(outerlipo_x, outerlipo_y, marker='.', color=(0,0.6,0),linestyle='none', markersize=4)
#_ = ax.plot(lipo_x, lipo_y, marker='.', color=(1,1,1),linestyle='none')
#_ = ax.plot(extracel_x, extracel_y, marker='.', color=(1,1,1),linestyle='none')
#_ = ax.plot(na_x, na_y, marker='.', color=(1,1,1),linestyle='none')
#_ = ax.plot(markerline_x, markerline_x, marker='.', color=(0,0,0),linestyle='none')

plt.plot([1, 1000000], [1, 1000000], '-',linewidth=1, color=(0,0,0))
# Add a legend
plt.legend(('integralmembrane','cytosolic','periplasmic','membrane_anchor','membrane_associated','outermembrane','outerlipo','lipo','extracellular','NA'), loc='upper left');

#Add a title
plt.title('SecA_5mMvs10mM_EDC_resin', fontsize=20, loc='center')

#calculate pearson correlation coefficient
x = data.loc[:,'5mM_EDC_resin']
y = data.loc[:,'10mM_EDC_resin']
print('pearson correlatin coefficient and p-value:')
print(sp.stats.pearsonr(x,y))
#plt.savefig('/Users/ShuaiWang/Desktop/Shan_Lab/Ribo_seq/Data_analysis/Shuai_Plot/xx.pdf')
# Out:
# pearson correlatin coefficient and p-value:
# (0.9950897413786226, 0.0)

# %%
import numpy as np

# Pandas, conventionally imported as pd
import pandas as pd

# Plotting modules and settings.
import matplotlib.pyplot as plt
import seaborn as sns
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728',
          '#9467bd', '#8c564b', '#e377c2', '#7f7f7f',
          '#bcbd22', '#17becf']
sns.set(style='whitegrid', palette=colors, rc={'axes.labelsize': 16})

# The following is specific Jupyter notebooks
# %matplotlib inline
# %config InlineBackend.figure_formats = {'png', 'retina'}


# Slice out x and y values
data = pd.read_csv('/Users/ShuaiWang/Desktop/Shan_Lab/Ribo_seq/Data_analysis/SecA_BrianRPM_043018.csv', comment='#')

integralmem_x = data.loc[(data['localization'] == 'IntegralMembraneProtein'),'5mM_EDC_resin']
integralmem_y = data.loc[(data['localization'] == 'IntegralMembraneProtein'),'60M_5mM_EDC_resin']

cyto_x = data.loc[(data['localization'] == 'Cytoplasmic'),'5mM_EDC_resin']
cyto_y = data.loc[(data['localization'] == 'Cytoplasmic'),'60M_5mM_EDC_resin']

peri_x = data.loc[(data['localization'] == 'Periplasmic'),'5mM_EDC_resin']
peri_y = data.loc[(data['localization'] == 'Periplasmic'),'60M_5mM_EDC_resin']

memanchor_x = data.loc[(data['localization'] == 'Membrane-anchored'),'5mM_EDC_resin']
memanchor_y = data.loc[(data['localization'] == 'Membrane-anchored'),'60M_5mM_EDC_resin']

memassoci_x = data.loc[(data['localization'] == 'Membraneassociated'),'5mM_EDC_resin']
memassoci_y = data.loc[(data['localization'] == 'Membraneassociated'),'60M_5mM_EDC_resin']

outermem_x = data.loc[(data['localization'] == 'OutermembraneProtein'),'5mM_EDC_resin']
outermem_y = data.loc[(data['localization'] == 'OutermembraneProtein'),'60M_5mM_EDC_resin']

outerlipo_x = data.loc[(data['localization'] == 'OutermembraneLipoprotein'),'5mM_EDC_resin']
outerlipo_y = data.loc[(data['localization'] == 'OutermembraneLipoprotein'),'60M_5mM_EDC_resin']

lipo_x = data.loc[(data['localization'] == 'Lipoprotein'),'5mM_EDC_resin']
lipo_y = data.loc[(data['localization'] == 'Lipoprotein'),'60M_5mM_EDC_resin']

extracel_x = data.loc[(data['localization'] == 'extracellular'),'5mM_EDC_resin']
extracel_y = data.loc[(data['localization'] == 'extracellular'),'60M_5mM_EDC_resin']

na_x = data.loc[(data['localization'] == '-'),'5mM_EDC_resin']
na_y = data.loc[(data['localization'] == '-'),'60M_5mM_EDC_resin']


# Make a plot with labeled axes, etc
fig, ax = plt.subplots(figsize=(15, 7.5))
ax.set_xlabel('10M_5mM_EDC_resin')
ax.set_ylabel('60M_5mM_EDC_resin')

plt.xscale('log')
plt.yscale('log')

# Make nice y-limits
ax.set_ylim(1, 1000000)
ax.set_xlim(1, 1000000)
plt.gca().set_aspect('equal', adjustable='box')


# plot content
_ = ax.plot(integralmem_x, integralmem_y, marker='.', color=(1,0,0),linestyle='none', markersize=4)
_ = ax.plot(cyto_x, cyto_y, marker='.', color=(0,0,1),linestyle='none', markersize=4)
_ = ax.plot(peri_x, peri_y, marker='.', color=(0,0.6,0),linestyle='none', markersize=4)
_ = ax.plot(memanchor_x, memanchor_y, marker='.', color=(1,0,0),linestyle='none', markersize=4)
_ = ax.plot(memassoci_x, memassoci_y, marker='.', color=(1,0,0),linestyle='none', markersize=4)
_ = ax.plot(outermem_x, outermem_y, marker='.', color=(0,0.6,0),linestyle='none', markersize=4)
_ = ax.plot(outerlipo_x, outerlipo_y, marker='.', color=(0,0.6,0),linestyle='none', markersize=4)
#_ = ax.plot(lipo_x, lipo_y, marker='.', color=(1,1,1),linestyle='none')
#_ = ax.plot(extracel_x, extracel_y, marker='.', color=(1,1,1),linestyle='none')
#_ = ax.plot(na_x, na_y, marker='.', color=(1,1,1),linestyle='none')
#_ = ax.plot(markerline_x, markerline_x, marker='.', color=(0,0,0),linestyle='none')

plt.plot([1, 1000000], [1, 1000000], '-',linewidth=1, color=(0,0,0))
# Add a legend
plt.legend(('integralmembrane','cytosolic','periplasmic','membrane_anchor','membrane_associated','outermembrane','outerlipo','lipo','extracellular','NA'), loc='upper left');

#Add a title
plt.title('SecA_5mM_10vs60M_read_resin', fontsize=20, loc='center')

#calculate pearson correlation coefficient
x = data.loc[:,'5mM_EDC_resin']
y = data.loc[:,'60M_5mM_EDC_resin']
print('pearson correlatin coefficient and p-value:')
print(sp.stats.pearsonr(x,y))
#plt.savefig('/Users/ShuaiWang/Desktop/Shan_Lab/Ribo_seq/Data_analysis/Shuai_Plot/xx.pdf')
# Out:
# pearson correlatin coefficient and p-value:
# (0.9964586662045116, 0.0)
