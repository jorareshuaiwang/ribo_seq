# %%
import numpy as np

# Pandas, conventionally imported as pd
import pandas as pd

# Plotting modules and settings.
import matplotlib.pyplot as plt
import seaborn as sns
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728',
          '#9467bd', '#8c564b', '#e377c2', '#7f7f7f',
          '#bcbd22', '#17becf']
sns.set(style='whitegrid', palette=colors, rc={'axes.labelsize': 16})

# The following is specific Jupyter notebooks
# %matplotlib inline
# %config InlineBackend.figure_formats = {'png', 'retina'}


# Slice out x and y values
data = pd.read_csv('/Users/ShuaiWang/Desktop/Shan_Lab/Ribo_seq/Data_analysis/SecA_BrianRPM_043018.csv', comment='#')

integralmem_x = data.loc[(data['localization'] == 'IntegralMembraneProtein'),'SRP_total_RPM']
integralmem_y = data.loc[(data['localization'] == 'IntegralMembraneProtein'),'SRP_IP_RPM']

cyto_x = data.loc[(data['localization'] == 'Cytoplasmic'),'SRP_total_RPM']
cyto_y = data.loc[(data['localization'] == 'Cytoplasmic'),'SRP_IP_RPM']

peri_x = data.loc[(data['localization'] == 'Periplasmic'),'SRP_total_RPM']
peri_y = data.loc[(data['localization'] == 'Periplasmic'),'SRP_IP_RPM']

memanchor_x = data.loc[(data['localization'] == 'Membrane-anchored'),'SRP_total_RPM']
memanchor_y = data.loc[(data['localization'] == 'Membrane-anchored'),'SRP_IP_RPM']

memassoci_x = data.loc[(data['localization'] == 'Membraneassociated'),'SRP_total_RPM']
memassoci_y = data.loc[(data['localization'] == 'Membraneassociated'),'SRP_IP_RPM']

outermem_x = data.loc[(data['localization'] == 'OutermembraneProtein'),'SRP_total_RPM']
outermem_y = data.loc[(data['localization'] == 'OutermembraneProtein'),'SRP_IP_RPM']

outerlipo_x = data.loc[(data['localization'] == 'OutermembraneLipoprotein'),'SRP_total_RPM']
outerlipo_y = data.loc[(data['localization'] == 'OutermembraneLipoprotein'),'SRP_IP_RPM']

lipo_x = data.loc[(data['localization'] == 'Lipoprotein'),'SRP_total_RPM']
lipo_y = data.loc[(data['localization'] == 'Lipoprotein'),'SRP_IP_RPM']

extracel_x = data.loc[(data['localization'] == 'extracellular'),'SRP_total_RPM']
extracel_y = data.loc[(data['localization'] == 'extracellular'),'SRP_IP_RPM']

na_x = data.loc[(data['localization'] == '-'),'SRP_total_RPM']
na_y = data.loc[(data['localization'] == '-'),'SRP_IP_RPM']

markerline_x= np.linspace(0, 1000000, 1000)

# Make a plot with labeled axes, etc
fig, ax = plt.subplots(figsize=(15, 7.5))
ax.set_xlabel('translatome')
ax.set_ylabel('interactome')

plt.xscale('log')
plt.yscale('log')

# Make nice y-limits
ax.set_ylim(1, 1000000)
ax.set_xlim(1, 1000000)
plt.gca().set_aspect('equal', adjustable='box')


# plot content
_ = ax.plot(integralmem_x, integralmem_y, marker='.', color=(1,0,0),linestyle='none', markersize=4)
_ = ax.plot(cyto_x, cyto_y, marker='.', color=(0,0,1),linestyle='none', markersize=4)
_ = ax.plot(peri_x, peri_y, marker='.', color=(0,0.6,0),linestyle='none', markersize=4)
_ = ax.plot(memanchor_x, memanchor_y, marker='.', color=(1,0,0),linestyle='none', markersize=4)
_ = ax.plot(memassoci_x, memassoci_y, marker='.', color=(1,0,0),linestyle='none', markersize=4)
_ = ax.plot(outermem_x, outermem_y, marker='.', color=(0,0.6,0),linestyle='none', markersize=4)
_ = ax.plot(outerlipo_x, outerlipo_y, marker='.', color=(0,0.6,0),linestyle='none', markersize=4)
#_ = ax.plot(lipo_x, lipo_y, marker='.', color=(1,1,1),linestyle='none')
#_ = ax.plot(extracel_x, extracel_y, marker='.', color=(1,1,1),linestyle='none')
#_ = ax.plot(na_x, na_y, marker='.', color=(1,1,1),linestyle='none')
#_ = ax.plot(markerline_x, markerline_x, marker='.', color=(0,0,0),linestyle='none')
plt.plot([1, 1000000], [1, 1000000], '-',linewidth=1, color=(0,0,0))
# Add a legend
plt.legend(('integralmembrane','cytosolic','periplasmic','membrane_anchor','membrane_associated','outermembrane','outerlipo','lipo','extracellular','NA'), loc='upper left');
#Add a title
plt.title('SRP', fontsize=20, loc='center')


plt.savefig('/Users/ShuaiWang/Desktop/Shan_Lab/Ribo_seq/Data_analysis/Shuai_Plot/SRP_RPM_enrichment.pdf')

# %%
import numpy as np

# Pandas, conventionally imported as pd
import pandas as pd

# Plotting modules and settings.
import matplotlib.pyplot as plt
import seaborn as sns
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728',
          '#9467bd', '#8c564b', '#e377c2', '#7f7f7f',
          '#bcbd22', '#17becf']
sns.set(style='whitegrid', palette=colors, rc={'axes.labelsize': 16})

# The following is specific Jupyter notebooks
# %matplotlib inline
# %config InlineBackend.figure_formats = {'png', 'retina'}


# Slice out x and y values
data = pd.read_csv('/Users/ShuaiWang/Desktop/Shan_Lab/Ribo_seq/Data_analysis/SecA_BrianRPM_043018.csv', comment='#')

integralmem_x = data.loc[(data['localization'] == 'IntegralMembraneProtein'),'5mM_EDC_input']
integralmem_y = data.loc[(data['localization'] == 'IntegralMembraneProtein'),'5mM_EDC_resin']

cyto_x = data.loc[(data['localization'] == 'Cytoplasmic'),'5mM_EDC_input']
cyto_y = data.loc[(data['localization'] == 'Cytoplasmic'),'5mM_EDC_resin']

peri_x = data.loc[(data['localization'] == 'Periplasmic'),'5mM_EDC_input']
peri_y = data.loc[(data['localization'] == 'Periplasmic'),'5mM_EDC_resin']

memanchor_x = data.loc[(data['localization'] == 'Membrane-anchored'),'5mM_EDC_input']
memanchor_y = data.loc[(data['localization'] == 'Membrane-anchored'),'5mM_EDC_resin']

memassoci_x = data.loc[(data['localization'] == 'Membraneassociated'),'5mM_EDC_input']
memassoci_y = data.loc[(data['localization'] == 'Membraneassociated'),'5mM_EDC_resin']

outermem_x = data.loc[(data['localization'] == 'OutermembraneProtein'),'5mM_EDC_input']
outermem_y = data.loc[(data['localization'] == 'OutermembraneProtein'),'5mM_EDC_resin']

outerlipo_x = data.loc[(data['localization'] == 'OutermembraneLipoprotein'),'5mM_EDC_input']
outerlipo_y = data.loc[(data['localization'] == 'OutermembraneLipoprotein'),'5mM_EDC_resin']

lipo_x = data.loc[(data['localization'] == 'Lipoprotein'),'5mM_EDC_input']
lipo_y = data.loc[(data['localization'] == 'Lipoprotein'),'5mM_EDC_resin']

extracel_x = data.loc[(data['localization'] == 'extracellular'),'5mM_EDC_input']
extracel_y = data.loc[(data['localization'] == 'extracellular'),'5mM_EDC_resin']

na_x = data.loc[(data['localization'] == '-'),'5mM_EDC_input']
na_y = data.loc[(data['localization'] == '-'),'5mM_EDC_resin']

markerline_x= np.linspace(0, 1000000, 1000)

# Make a plot with labeled axes, etc
fig, ax = plt.subplots(figsize=(15, 7.5))
ax.set_xlabel('translatome')
ax.set_ylabel('interactome')

plt.xscale('log')
plt.yscale('log')

# Make nice y-limits
ax.set_ylim(1, 1000000)
ax.set_xlim(1, 1000000)
plt.gca().set_aspect('equal', adjustable='box')


# plot content
_ = ax.plot(integralmem_x, integralmem_y, marker='.', color=(1,0,0),linestyle='none', markersize=4)
_ = ax.plot(cyto_x, cyto_y, marker='.', color=(0,0,1),linestyle='none', markersize=4)
_ = ax.plot(peri_x, peri_y, marker='.', color=(0,0.6,0),linestyle='none', markersize=4)
_ = ax.plot(memanchor_x, memanchor_y, marker='.', color=(1,0,0),linestyle='none', markersize=4)
_ = ax.plot(memassoci_x, memassoci_y, marker='.', color=(1,0,0),linestyle='none', markersize=4)
_ = ax.plot(outermem_x, outermem_y, marker='.', color=(0,0.6,0),linestyle='none', markersize=4)
_ = ax.plot(outerlipo_x, outerlipo_y, marker='.', color=(0,0.6,0),linestyle='none', markersize=4)
#_ = ax.plot(lipo_x, lipo_y, marker='.', color=(1,1,1),linestyle='none')
#_ = ax.plot(extracel_x, extracel_y, marker='.', color=(1,1,1),linestyle='none')
#_ = ax.plot(na_x, na_y, marker='.', color=(1,1,1),linestyle='none')
#_ = ax.plot(markerline_x, markerline_x, marker='.', color=(0,0,0),linestyle='none')
plt.plot([1, 1000000], [1, 1000000], '-',linewidth=1, color=(0,0,0))
# Add a legend
plt.legend(('integralmembrane','cytosolic','periplasmic','membrane_anchor','membrane_associated','outermembrane','outerlipo','lipo','extracellular','NA'), loc='upper left');

#Add a title
plt.title('SecA_5mM_EDC_BrianRPM_10M', fontsize=20, loc='center')

plt.savefig('/Users/ShuaiWang/Desktop/Shan_Lab/Ribo_seq/Data_analysis/Shuai_Plot/SecA_5mM_EDC_BrianRPM_10M.pdf')

# %%
import numpy as np

# Pandas, conventionally imported as pd
import pandas as pd

# Plotting modules and settings.
import matplotlib.pyplot as plt
import seaborn as sns
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728',
          '#9467bd', '#8c564b', '#e377c2', '#7f7f7f',
          '#bcbd22', '#17becf']
sns.set(style='whitegrid', palette=colors, rc={'axes.labelsize': 16})

# The following is specific Jupyter notebooks
# %matplotlib inline
# %config InlineBackend.figure_formats = {'png', 'retina'}


# Slice out x and y values
data = pd.read_csv('/Users/ShuaiWang/Desktop/Shan_Lab/Ribo_seq/Data_analysis/SecA_BrianRPM_043018.csv', comment='#')

integralmem_x = data.loc[(data['localization'] == 'IntegralMembraneProtein'),'10mM_EDC_input']
integralmem_y = data.loc[(data['localization'] == 'IntegralMembraneProtein'),'10mM_EDC_resin']

cyto_x = data.loc[(data['localization'] == 'Cytoplasmic'),'10mM_EDC_input']
cyto_y = data.loc[(data['localization'] == 'Cytoplasmic'),'10mM_EDC_resin']

peri_x = data.loc[(data['localization'] == 'Periplasmic'),'10mM_EDC_input']
peri_y = data.loc[(data['localization'] == 'Periplasmic'),'10mM_EDC_resin']

memanchor_x = data.loc[(data['localization'] == 'Membrane-anchored'),'10mM_EDC_input']
memanchor_y = data.loc[(data['localization'] == 'Membrane-anchored'),'10mM_EDC_resin']

memassoci_x = data.loc[(data['localization'] == 'Membraneassociated'),'10mM_EDC_input']
memassoci_y = data.loc[(data['localization'] == 'Membraneassociated'),'10mM_EDC_resin']

outermem_x = data.loc[(data['localization'] == 'OutermembraneProtein'),'10mM_EDC_input']
outermem_y = data.loc[(data['localization'] == 'OutermembraneProtein'),'10mM_EDC_resin']

outerlipo_x = data.loc[(data['localization'] == 'OutermembraneLipoprotein'),'10mM_EDC_input']
outerlipo_y = data.loc[(data['localization'] == 'OutermembraneLipoprotein'),'10mM_EDC_resin']

lipo_x = data.loc[(data['localization'] == 'Lipoprotein'),'10mM_EDC_input']
lipo_y = data.loc[(data['localization'] == 'Lipoprotein'),'10mM_EDC_resin']

extracel_x = data.loc[(data['localization'] == 'extracellular'),'10mM_EDC_input']
extracel_y = data.loc[(data['localization'] == 'extracellular'),'10mM_EDC_resin']

na_x = data.loc[(data['localization'] == '-'),'10mM_EDC_input']
na_y = data.loc[(data['localization'] == '-'),'10mM_EDC_resin']

markerline_x= np.linspace(0, 1000000, 1000)

# Make a plot with labeled axes, etc
fig, ax = plt.subplots(figsize=(15, 7.5))
ax.set_xlabel('translatome')
ax.set_ylabel('interactome')

plt.xscale('log')
plt.yscale('log')

# Make nice y-limits
ax.set_ylim(1, 1000000)
ax.set_xlim(1, 1000000)
plt.gca().set_aspect('equal', adjustable='box')


# plot content
_ = ax.plot(integralmem_x, integralmem_y, marker='.', color=(1,0,0),linestyle='none', markersize=4)
_ = ax.plot(cyto_x, cyto_y, marker='.', color=(0,0,1),linestyle='none', markersize=4)
_ = ax.plot(peri_x, peri_y, marker='.', color=(0,0.6,0),linestyle='none', markersize=4)
_ = ax.plot(memanchor_x, memanchor_y, marker='.', color=(1,0,0),linestyle='none', markersize=4)
_ = ax.plot(memassoci_x, memassoci_y, marker='.', color=(1,0,0),linestyle='none', markersize=4)
_ = ax.plot(outermem_x, outermem_y, marker='.', color=(0,0.6,0),linestyle='none', markersize=4)
_ = ax.plot(outerlipo_x, outerlipo_y, marker='.', color=(0,0.6,0),linestyle='none', markersize=4)
#_ = ax.plot(lipo_x, lipo_y, marker='.', color=(1,1,1),linestyle='none')
#_ = ax.plot(extracel_x, extracel_y, marker='.', color=(1,1,1),linestyle='none')
#_ = ax.plot(na_x, na_y, marker='.', color=(1,1,1),linestyle='none')
#_ = ax.plot(markerline_x, markerline_x, marker='.', color=(0,0,0),linestyle='none')
plt.plot([1, 1000000], [1, 1000000], '-',linewidth=1, color=(0,0,0))
# Add a legend
plt.legend(('integralmembrane','cytosolic','periplasmic','membrane_anchor','membrane_associated','outermembrane','outerlipo','lipo','extracellular','NA'), loc='upper left');

#Add a title
plt.title('SecA_10mM_EDC_BrianRPM_10M', fontsize=20, loc='center')

plt.savefig('/Users/ShuaiWang/Desktop/Shan_Lab/Ribo_seq/Data_analysis/Shuai_Plot/SecA_10mM_EDC_BrianRPM_10M.pdf')

# %%
import numpy as np

# Pandas, conventionally imported as pd
import pandas as pd

# Plotting modules and settings.
import matplotlib.pyplot as plt
import seaborn as sns
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728',
          '#9467bd', '#8c564b', '#e377c2', '#7f7f7f',
          '#bcbd22', '#17becf']
sns.set(style='whitegrid', palette=colors, rc={'axes.labelsize': 16})

# The following is specific Jupyter notebooks
# %matplotlib inline
# %config InlineBackend.figure_formats = {'png', 'retina'}


# Slice out x and y values
data = pd.read_csv('/Users/ShuaiWang/Desktop/Shan_Lab/Ribo_seq/Data_analysis/SecA_BukauRPM_043018.csv', comment='#')

integralmem_x = data.loc[(data['localization'] == 'IntegralMembraneProtein'),'10M_5mM_EDC_input']
integralmem_y = data.loc[(data['localization'] == 'IntegralMembraneProtein'),'10M_5mM_EDC_resin']

cyto_x = data.loc[(data['localization'] == 'Cytoplasmic'),'10M_5mM_EDC_input']
cyto_y = data.loc[(data['localization'] == 'Cytoplasmic'),'10M_5mM_EDC_resin']

peri_x = data.loc[(data['localization'] == 'Periplasmic'),'10M_5mM_EDC_input']
peri_y = data.loc[(data['localization'] == 'Periplasmic'),'10M_5mM_EDC_resin']

memanchor_x = data.loc[(data['localization'] == 'Membrane-anchored'),'10M_5mM_EDC_input']
memanchor_y = data.loc[(data['localization'] == 'Membrane-anchored'),'10M_5mM_EDC_resin']

memassoci_x = data.loc[(data['localization'] == 'Membraneassociated'),'10M_5mM_EDC_input']
memassoci_y = data.loc[(data['localization'] == 'Membraneassociated'),'10M_5mM_EDC_resin']

outermem_x = data.loc[(data['localization'] == 'OutermembraneProtein'),'10M_5mM_EDC_input']
outermem_y = data.loc[(data['localization'] == 'OutermembraneProtein'),'10M_5mM_EDC_resin']

outerlipo_x = data.loc[(data['localization'] == 'OutermembraneLipoprotein'),'10M_5mM_EDC_input']
outerlipo_y = data.loc[(data['localization'] == 'OutermembraneLipoprotein'),'10M_5mM_EDC_resin']

lipo_x = data.loc[(data['localization'] == 'Lipoprotein'),'10M_5mM_EDC_input']
lipo_y = data.loc[(data['localization'] == 'Lipoprotein'),'10M_5mM_EDC_resin']

extracel_x = data.loc[(data['localization'] == 'extracellular'),'10M_5mM_EDC_input']
extracel_y = data.loc[(data['localization'] == 'extracellular'),'10M_5mM_EDC_resin']

na_x = data.loc[(data['localization'] == '-'),'10M_5mM_EDC_input']
na_y = data.loc[(data['localization'] == '-'),'10M_5mM_EDC_resin']



# Make a plot with labeled axes, etc

fig, ax = plt.subplots(figsize=(15, 7.5))
ax.set_xlabel('translatome')
ax.set_ylabel('interactome')

plt.xscale('log')
plt.yscale('log')

# Make nice y-limits
ax.set_ylim(1, 1000000)
ax.set_xlim(1, 1000000)
plt.gca().set_aspect('equal', adjustable='box')


# plot content
_ = ax.plot(integralmem_x, integralmem_y, marker='.', color=(1,0,0),linestyle='none', markersize=4)
_ = ax.plot(cyto_x, cyto_y, marker='.', color=(0,0,1),linestyle='none', markersize=4)
_ = ax.plot(peri_x, peri_y, marker='.', color=(0,0.6,0),linestyle='none', markersize=4)
_ = ax.plot(memanchor_x, memanchor_y, marker='.', color=(1,0,0),linestyle='none', markersize=4)
_ = ax.plot(memassoci_x, memassoci_y, marker='.', color=(1,0,0),linestyle='none', markersize=4)
_ = ax.plot(outermem_x, outermem_y, marker='.', color=(0,0.6,0),linestyle='none', markersize=4)
_ = ax.plot(outerlipo_x, outerlipo_y, marker='.', color=(0,0.6,0),linestyle='none', markersize=4)
#_ = ax.plot(lipo_x, lipo_y, marker='.', color=(1,1,1),linestyle='none')
#_ = ax.plot(extracel_x, extracel_y, marker='.', color=(1,1,1),linestyle='none')
#_ = ax.plot(na_x, na_y, marker='.', color=(1,1,1),linestyle='none')
#_ = ax.plot(markerline_x, markerline_x, marker='.', color=(0,0,0),linestyle='none')

plt.plot([1, 1000000], [1, 1000000], '-',linewidth=1, color=(0,0,0))

# Add a legend
plt.legend(('integralmembrane','cytosolic','periplasmic','membrane_anchor','membrane_associated','outermembrane','outerlipo','lipo','extracellular','NA'), loc='upper left');

#add title
plt.title('SecA_5mM_EDC_BukauRPM_10M', fontsize=20, loc='center')
plt.savefig('/Users/ShuaiWang/Desktop/Shan_Lab/Ribo_seq/Data_analysis/Shuai_Plot/SecA_5mM_EDC_BukauRPM_10M.pdf')

# %%
import numpy as np

# Pandas, conventionally imported as pd
import pandas as pd

# Plotting modules and settings.
import matplotlib.pyplot as plt
import seaborn as sns
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728',
          '#9467bd', '#8c564b', '#e377c2', '#7f7f7f',
          '#bcbd22', '#17becf']
sns.set(style='whitegrid', palette=colors, rc={'axes.labelsize': 16})

# The following is specific Jupyter notebooks
# %matplotlib inline
# %config InlineBackend.figure_formats = {'png', 'retina'}


# Slice out x and y values
data = pd.read_csv('/Users/ShuaiWang/Desktop/Shan_Lab/Ribo_seq/Data_analysis/SecA_BukauRPM_043018.csv', comment='#')

integralmem_x = data.loc[(data['localization'] == 'IntegralMembraneProtein'),'10M_10mM_EDC_input_x']
integralmem_y = data.loc[(data['localization'] == 'IntegralMembraneProtein'),'10M_10mM_EDC_resin_x']

cyto_x = data.loc[(data['localization'] == 'Cytoplasmic'),'10M_10mM_EDC_input_x']
cyto_y = data.loc[(data['localization'] == 'Cytoplasmic'),'10M_10mM_EDC_resin_x']

peri_x = data.loc[(data['localization'] == 'Periplasmic'),'10M_10mM_EDC_input_x']
peri_y = data.loc[(data['localization'] == 'Periplasmic'),'10M_10mM_EDC_resin_x']

memanchor_x = data.loc[(data['localization'] == 'Membrane-anchored'),'10M_10mM_EDC_input_x']
memanchor_y = data.loc[(data['localization'] == 'Membrane-anchored'),'10M_10mM_EDC_resin_x']

memassoci_x = data.loc[(data['localization'] == 'Membraneassociated'),'10M_10mM_EDC_input_x']
memassoci_y = data.loc[(data['localization'] == 'Membraneassociated'),'10M_10mM_EDC_resin_x']

outermem_x = data.loc[(data['localization'] == 'OutermembraneProtein'),'10M_10mM_EDC_input_x']
outermem_y = data.loc[(data['localization'] == 'OutermembraneProtein'),'10M_10mM_EDC_resin_x']

outerlipo_x = data.loc[(data['localization'] == 'OutermembraneLipoprotein'),'10M_10mM_EDC_input_x']
outerlipo_y = data.loc[(data['localization'] == 'OutermembraneLipoprotein'),'10M_10mM_EDC_resin_x']

lipo_x = data.loc[(data['localization'] == 'Lipoprotein'),'10M_10mM_EDC_input_x']
lipo_y = data.loc[(data['localization'] == 'Lipoprotein'),'10M_10mM_EDC_resin_x']

extracel_x = data.loc[(data['localization'] == 'extracellular'),'10M_10mM_EDC_input_x']
extracel_y = data.loc[(data['localization'] == 'extracellular'),'10M_10mM_EDC_resin_x']

na_x = data.loc[(data['localization'] == '-'),'10M_10mM_EDC_input_x']
na_y = data.loc[(data['localization'] == '-'),'10M_10mM_EDC_resin_x']



# Make a plot with labeled axes, etc

fig, ax = plt.subplots(figsize=(15, 7.5))
ax.set_xlabel('translatome')
ax.set_ylabel('interactome')

plt.xscale('log')
plt.yscale('log')

# Make nice y-limits
ax.set_ylim(1, 1000000)
ax.set_xlim(1, 1000000)
plt.gca().set_aspect('equal', adjustable='box')


# plot content
_ = ax.plot(integralmem_x, integralmem_y, marker='.', color=(1,0,0),linestyle='none', markersize=4)
_ = ax.plot(cyto_x, cyto_y, marker='.', color=(0,0,1),linestyle='none', markersize=4)
_ = ax.plot(peri_x, peri_y, marker='.', color=(0,0.6,0),linestyle='none', markersize=4)
_ = ax.plot(memanchor_x, memanchor_y, marker='.', color=(1,0,0),linestyle='none', markersize=4)
_ = ax.plot(memassoci_x, memassoci_y, marker='.', color=(1,0,0),linestyle='none', markersize=4)
_ = ax.plot(outermem_x, outermem_y, marker='.', color=(0,0.6,0),linestyle='none', markersize=4)
_ = ax.plot(outerlipo_x, outerlipo_y, marker='.', color=(0,0.6,0),linestyle='none', markersize=4)
#_ = ax.plot(lipo_x, lipo_y, marker='.', color=(1,1,1),linestyle='none')
#_ = ax.plot(extracel_x, extracel_y, marker='.', color=(1,1,1),linestyle='none')
#_ = ax.plot(na_x, na_y, marker='.', color=(1,1,1),linestyle='none')
#_ = ax.plot(markerline_x, markerline_x, marker='.', color=(0,0,0),linestyle='none')

plt.plot([1, 1000000], [1, 1000000], '-',linewidth=1, color=(0,0,0))

# Add a legend
plt.legend(('integralmembrane','cytosolic','periplasmic','membrane_anchor','membrane_associated','outermembrane','outerlipo','lipo','extracellular','NA'), loc='upper left');

#add title
plt.title('SecA_10mM_EDC_BukauRPM_10M', fontsize=20, loc='center')
plt.savefig('/Users/ShuaiWang/Desktop/Shan_Lab/Ribo_seq/Data_analysis/Shuai_Plot/SecA_10mM_EDC_BukauRPM_10M.pdf')

# %%
import numpy as np

# Pandas, conventionally imported as pd
import pandas as pd

# Plotting modules and settings.
import matplotlib.pyplot as plt
import seaborn as sns
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728',
          '#9467bd', '#8c564b', '#e377c2', '#7f7f7f',
          '#bcbd22', '#17becf']
sns.set(style='whitegrid', palette=colors, rc={'axes.labelsize': 16})

# The following is specific Jupyter notebooks
# %matplotlib inline
# %config InlineBackend.figure_formats = {'png', 'retina'}


# Slice out x and y values
data = pd.read_csv('/Users/ShuaiWang/Desktop/Shan_Lab/Ribo_seq/Data_analysis/SecA_BrianRPM_043018.csv', comment='#')

integralmem_x = data.loc[(data['localization'] == 'IntegralMembraneProtein'),'60M_5mM_EDC_input']
integralmem_y = data.loc[(data['localization'] == 'IntegralMembraneProtein'),'60M_5mM_EDC_resin']

cyto_x = data.loc[(data['localization'] == 'Cytoplasmic'),'60M_5mM_EDC_input']
cyto_y = data.loc[(data['localization'] == 'Cytoplasmic'),'60M_5mM_EDC_resin']

peri_x = data.loc[(data['localization'] == 'Periplasmic'),'60M_5mM_EDC_input']
peri_y = data.loc[(data['localization'] == 'Periplasmic'),'60M_5mM_EDC_resin']

memanchor_x = data.loc[(data['localization'] == 'Membrane-anchored'),'60M_5mM_EDC_input']
memanchor_y = data.loc[(data['localization'] == 'Membrane-anchored'),'60M_5mM_EDC_resin']

memassoci_x = data.loc[(data['localization'] == 'Membraneassociated'),'60M_5mM_EDC_input']
memassoci_y = data.loc[(data['localization'] == 'Membraneassociated'),'60M_5mM_EDC_resin']

outermem_x = data.loc[(data['localization'] == 'OutermembraneProtein'),'60M_5mM_EDC_input']
outermem_y = data.loc[(data['localization'] == 'OutermembraneProtein'),'60M_5mM_EDC_resin']

outerlipo_x = data.loc[(data['localization'] == 'OutermembraneLipoprotein'),'60M_5mM_EDC_input']
outerlipo_y = data.loc[(data['localization'] == 'OutermembraneLipoprotein'),'60M_5mM_EDC_resin']

lipo_x = data.loc[(data['localization'] == 'Lipoprotein'),'60M_5mM_EDC_input']
lipo_y = data.loc[(data['localization'] == 'Lipoprotein'),'60M_5mM_EDC_resin']

extracel_x = data.loc[(data['localization'] == 'extracellular'),'60M_5mM_EDC_input']
extracel_y = data.loc[(data['localization'] == 'extracellular'),'60M_5mM_EDC_resin']

na_x = data.loc[(data['localization'] == '-'),'60M_5mM_EDC_input']
na_y = data.loc[(data['localization'] == '-'),'60M_5mM_EDC_resin']

markerline_x= np.linspace(0, 1000000, 1000)

# Make a plot with labeled axes, etc
fig, ax = plt.subplots(figsize=(15, 7.5))
ax.set_xlabel('translatome')
ax.set_ylabel('interactome')

plt.xscale('log')
plt.yscale('log')

# Make nice y-limits
ax.set_ylim(1, 1000000)
ax.set_xlim(1, 1000000)
plt.gca().set_aspect('equal', adjustable='box')


# plot content
_ = ax.plot(integralmem_x, integralmem_y, marker='.', color=(1,0,0),linestyle='none', markersize=4)
_ = ax.plot(cyto_x, cyto_y, marker='.', color=(0,0,1),linestyle='none', markersize=4)
_ = ax.plot(peri_x, peri_y, marker='.', color=(0,0.6,0),linestyle='none', markersize=4)
_ = ax.plot(memanchor_x, memanchor_y, marker='.', color=(1,0,0),linestyle='none', markersize=4)
_ = ax.plot(memassoci_x, memassoci_y, marker='.', color=(1,0,0),linestyle='none', markersize=4)
_ = ax.plot(outermem_x, outermem_y, marker='.', color=(0,0.6,0),linestyle='none', markersize=4)
_ = ax.plot(outerlipo_x, outerlipo_y, marker='.', color=(0,0.6,0),linestyle='none', markersize=4)
#_ = ax.plot(lipo_x, lipo_y, marker='.', color=(1,1,1),linestyle='none')
#_ = ax.plot(extracel_x, extracel_y, marker='.', color=(1,1,1),linestyle='none')
#_ = ax.plot(na_x, na_y, marker='.', color=(1,1,1),linestyle='none')
#_ = ax.plot(markerline_x, markerline_x, marker='.', color=(0,0,0),linestyle='none')
plt.plot([1, 1000000], [1, 1000000], '-',linewidth=1, color=(0,0,0))
# Add a legend
plt.legend(('integralmembrane','cytosolic','periplasmic','membrane_anchor','membrane_associated','outermembrane','outerlipo','lipo','extracellular','NA'), loc='upper left');

#Add a title
plt.title('SecA_5mM_EDC_BrianRPM_60M', fontsize=20, loc='center')

plt.savefig('/Users/ShuaiWang/Desktop/Shan_Lab/Ribo_seq/Data_analysis/Shuai_Plot/SecA_5mM_EDC_BrianRPM_60M.pdf')

# %%
import numpy as np

# Pandas, conventionally imported as pd
import pandas as pd

# Plotting modules and settings.
import matplotlib.pyplot as plt
import seaborn as sns
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728',
          '#9467bd', '#8c564b', '#e377c2', '#7f7f7f',
          '#bcbd22', '#17becf']
sns.set(style='whitegrid', palette=colors, rc={'axes.labelsize': 16})

# The following is specific Jupyter notebooks
# %matplotlib inline
# %config InlineBackend.figure_formats = {'png', 'retina'}


# Slice out x and y values
data = pd.read_csv('/Users/ShuaiWang/Desktop/Shan_Lab/Ribo_seq/Data_analysis/SecA_BukauRPM_043018.csv', comment='#')

integralmem_x = data.loc[(data['localization'] == 'IntegralMembraneProtein'),'60M_5mM_EDC_input']
integralmem_y = data.loc[(data['localization'] == 'IntegralMembraneProtein'),'60M_5mM_EDC_resin']

cyto_x = data.loc[(data['localization'] == 'Cytoplasmic'),'60M_5mM_EDC_input']
cyto_y = data.loc[(data['localization'] == 'Cytoplasmic'),'60M_5mM_EDC_resin']

peri_x = data.loc[(data['localization'] == 'Periplasmic'),'60M_5mM_EDC_input']
peri_y = data.loc[(data['localization'] == 'Periplasmic'),'60M_5mM_EDC_resin']

memanchor_x = data.loc[(data['localization'] == 'Membrane-anchored'),'60M_5mM_EDC_input']
memanchor_y = data.loc[(data['localization'] == 'Membrane-anchored'),'60M_5mM_EDC_resin']

memassoci_x = data.loc[(data['localization'] == 'Membraneassociated'),'60M_5mM_EDC_input']
memassoci_y = data.loc[(data['localization'] == 'Membraneassociated'),'60M_5mM_EDC_resin']

outermem_x = data.loc[(data['localization'] == 'OutermembraneProtein'),'60M_5mM_EDC_input']
outermem_y = data.loc[(data['localization'] == 'OutermembraneProtein'),'60M_5mM_EDC_resin']

outerlipo_x = data.loc[(data['localization'] == 'OutermembraneLipoprotein'),'60M_5mM_EDC_input']
outerlipo_y = data.loc[(data['localization'] == 'OutermembraneLipoprotein'),'60M_5mM_EDC_resin']

lipo_x = data.loc[(data['localization'] == 'Lipoprotein'),'60M_5mM_EDC_input']
lipo_y = data.loc[(data['localization'] == 'Lipoprotein'),'60M_5mM_EDC_resin']

extracel_x = data.loc[(data['localization'] == 'extracellular'),'60M_5mM_EDC_input']
extracel_y = data.loc[(data['localization'] == 'extracellular'),'60M_5mM_EDC_resin']

na_x = data.loc[(data['localization'] == '-'),'60M_5mM_EDC_input']
na_y = data.loc[(data['localization'] == '-'),'60M_5mM_EDC_resin']

markerline_x= np.linspace(0, 1000000, 1000)

# Make a plot with labeled axes, etc

fig, ax = plt.subplots(figsize=(15, 7.5))
ax.set_xlabel('translatome')
ax.set_ylabel('interactome')

plt.xscale('log')
plt.yscale('log')

# Make nice y-limits
ax.set_ylim(1, 1000000)
ax.set_xlim(1, 1000000)
plt.gca().set_aspect('equal', adjustable='box')


# plot content
_ = ax.plot(integralmem_x, integralmem_y, marker='.', color=(1,0,0),linestyle='none', markersize=4)
_ = ax.plot(cyto_x, cyto_y, marker='.', color=(0,0,1),linestyle='none', markersize=4)
_ = ax.plot(peri_x, peri_y, marker='.', color=(0,0.6,0),linestyle='none', markersize=4)
_ = ax.plot(memanchor_x, memanchor_y, marker='.', color=(1,0,0),linestyle='none', markersize=4)
_ = ax.plot(memassoci_x, memassoci_y, marker='.', color=(1,0,0),linestyle='none', markersize=4)
_ = ax.plot(outermem_x, outermem_y, marker='.', color=(0,0.6,0),linestyle='none', markersize=4)
_ = ax.plot(outerlipo_x, outerlipo_y, marker='.', color=(0,0.6,0),linestyle='none', markersize=4)
#_ = ax.plot(lipo_x, lipo_y, marker='.', color=(1,1,1),linestyle='none')
#_ = ax.plot(extracel_x, extracel_y, marker='.', color=(1,1,1),linestyle='none')
#_ = ax.plot(na_x, na_y, marker='.', color=(1,1,1),linestyle='none')
#_ = ax.plot(markerline_x, markerline_x, marker='.', color=(0,0,0),linestyle='none')
plt.plot([1, 1000000], [1, 1000000], '-',linewidth=1, color=(0,0,0))
# Add a legend
plt.legend(('integralmembrane','cytosolic','periplasmic','membrane_anchor','membrane_associated','outermembrane','outerlipo','lipo','extracellular','NA'), loc='upper left');

#add title
plt.title('SecA_5mM_EDC_BukauRPM_60M', fontsize=20, loc='center')

plt.savefig('/Users/ShuaiWang/Desktop/Shan_Lab/Ribo_seq/Data_analysis/Shuai_Plot/SecA_5mM_EDC_BukauRPM_60M.pdf')

# %%
import numpy as np

# Pandas, conventionally imported as pd
import pandas as pd

import scipy as sp
# Plotting modules and settings.
import matplotlib.pyplot as plt
import seaborn as sns
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728',
          '#9467bd', '#8c564b', '#e377c2', '#7f7f7f',
          '#bcbd22', '#17becf']
sns.set(style='whitegrid', palette=colors, rc={'axes.labelsize': 16})

# The following is specific Jupyter notebooks
# %matplotlib inline
# %config InlineBackend.figure_formats = {'png', 'retina'}


# Slice out x and y values
data = pd.read_csv('/Users/ShuaiWang/Desktop/Shan_Lab/Ribo_seq/03172018/input_5mM/50M/5mM_50M_RPM_ORF_Shuaiprocess.csv', comment='#')

integralmem_x = data.loc[(data['localization'] == 'IntegralMembraneProtein'),'50M_5mM_input_weightedRPM']
integralmem_y = data.loc[(data['localization'] == 'IntegralMembraneProtein'),'50M_5mM_resin_weightedRPM']

cyto_x = data.loc[(data['localization'] == 'Cytoplasmic'),'50M_5mM_input_weightedRPM']
cyto_y = data.loc[(data['localization'] == 'Cytoplasmic'),'50M_5mM_resin_weightedRPM']

peri_x = data.loc[(data['localization'] == 'Periplasmic'),'50M_5mM_input_weightedRPM']
peri_y = data.loc[(data['localization'] == 'Periplasmic'),'50M_5mM_resin_weightedRPM']

memanchor_x = data.loc[(data['localization'] == 'Membrane-anchored'),'50M_5mM_input_weightedRPM']
memanchor_y = data.loc[(data['localization'] == 'Membrane-anchored'),'50M_5mM_resin_weightedRPM']

memassoci_x = data.loc[(data['localization'] == 'Membraneassociated'),'50M_5mM_input_weightedRPM']
memassoci_y = data.loc[(data['localization'] == 'Membraneassociated'),'50M_5mM_resin_weightedRPM']

outermem_x = data.loc[(data['localization'] == 'OutermembraneProtein'),'50M_5mM_input_weightedRPM']
outermem_y = data.loc[(data['localization'] == 'OutermembraneProtein'),'50M_5mM_resin_weightedRPM']

outerlipo_x = data.loc[(data['localization'] == 'OutermembraneLipoprotein'),'50M_5mM_input_weightedRPM']
outerlipo_y = data.loc[(data['localization'] == 'OutermembraneLipoprotein'),'50M_5mM_resin_weightedRPM']

lipo_x = data.loc[(data['localization'] == 'Lipoprotein'),'50M_5mM_input_weightedRPM']
lipo_y = data.loc[(data['localization'] == 'Lipoprotein'),'50M_5mM_resin_weightedRPM']

extracel_x = data.loc[(data['localization'] == 'extracellular'),'50M_5mM_input_weightedRPM']
extracel_y = data.loc[(data['localization'] == 'extracellular'),'50M_5mM_resin_weightedRPM']

na_x = data.loc[(data['localization'] == '-'),'50M_5mM_input_weightedRPM']
na_y = data.loc[(data['localization'] == '-'),'50M_5mM_resin_weightedRPM']


# Make a plot with labeled axes, etc
fig, ax = plt.subplots(figsize=(15, 7.5))
ax.set_xlabel('translatome')
ax.set_ylabel('interactome')

plt.xscale('log')
plt.yscale('log')

# Make nice y-limits
ax.set_ylim(1, 1000000)
ax.set_xlim(1, 1000000)
plt.gca().set_aspect('equal', adjustable='box')


# plot content
_ = ax.plot(integralmem_x, integralmem_y, marker='.', color=(1,0,0),linestyle='none', markersize=4)
_ = ax.plot(cyto_x, cyto_y, marker='.', color=(0,0,1),linestyle='none', markersize=4)
_ = ax.plot(peri_x, peri_y, marker='.', color=(0,0.6,0),linestyle='none', markersize=4)
_ = ax.plot(memanchor_x, memanchor_y, marker='.', color=(1,0,0),linestyle='none', markersize=4)
_ = ax.plot(memassoci_x, memassoci_y, marker='.', color=(1,0,0),linestyle='none', markersize=4)
_ = ax.plot(outermem_x, outermem_y, marker='.', color=(0,0.6,0),linestyle='none', markersize=4)
_ = ax.plot(outerlipo_x, outerlipo_y, marker='.', color=(0,0.6,0),linestyle='none', markersize=4)
#_ = ax.plot(lipo_x, lipo_y, marker='.', color=(1,1,1),linestyle='none')
#_ = ax.plot(extracel_x, extracel_y, marker='.', color=(1,1,1),linestyle='none')
#_ = ax.plot(na_x, na_y, marker='.', color=(1,1,1),linestyle='none')
#_ = ax.plot(markerline_x, markerline_x, marker='.', color=(0,0,0),linestyle='none')

#diagonal marker line
diagonal_x=[1, 1000000]
diagonal_y=[1, 1000000]

#boundary marker line
bound_x=[i*1 for i in diagonal_x]
bound_y=[i*1.5 for i in diagonal_y]

plt.plot(diagonal_x, diagonal_y, '-',linewidth=1, color=(0,0,0))
plt.plot(bound_x, bound_y,linewidth=2,linestyle='--', color='#808080')
# Add a legend
plt.legend(('integralmembrane','cytosolic','periplasmic','membrane_anchor','membrane_associated','outermembrane','outerlipo','lipo','extracellular','NA'), loc='upper left');
#Add a title
plt.title('SecA_5mMEDC_50M_Shuai_data', fontsize=20, loc='center')

#calculate pearson correlation coefficient
#x = data.loc[:,'SRP_total_RPM']
#y = data.loc[:,'SRP_IP_RPM']
#print('pearson correlatin coefficient and p-value:')
#print(sp.stats.pearsonr(x,y))

#plt.savefig('/Users/ShuaiWang/Desktop/Shan_Lab/Ribo_seq/Data_analysis/Shuai_Plot/SRP_RPM_enrichment.pdf')
# Out:
# Text(0.5,1,'SecA_5mMEDC_50M_Shuai_data')

# %%
import numpy as np

# Pandas, conventionally imported as pd
import pandas as pd

import scipy as sp
# Plotting modules and settings.
import matplotlib.pyplot as plt
import seaborn as sns
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728',
          '#9467bd', '#8c564b', '#e377c2', '#7f7f7f',
          '#bcbd22', '#17becf']
sns.set(style='whitegrid', palette=colors, rc={'axes.labelsize': 16})

# The following is specific Jupyter notebooks
# %matplotlib inline
# %config InlineBackend.figure_formats = {'png', 'retina'}


# Slice out x and y values
data = pd.read_csv('/Users/ShuaiWang/Desktop/Shan_Lab/Ribo_seq/compiled_data/center_weighted_RPM_050918.csv', comment='#')

integralmem_x = data.loc[(data['localization'] == 'IntegralMembraneProtein'),'5mM_EDC_10M_resin_RPM_center_weighted']
integralmem_y = data.loc[(data['localization'] == 'IntegralMembraneProtein'),'50M_5mM_resin_weightedRPM']

cyto_x = data.loc[(data['localization'] == 'Cytoplasmic'),'5mM_EDC_10M_resin_RPM_center_weighted']
cyto_y = data.loc[(data['localization'] == 'Cytoplasmic'),'50M_5mM_resin_weightedRPM']

peri_x = data.loc[(data['localization'] == 'Periplasmic'),'5mM_EDC_10M_resin_RPM_center_weighted']
peri_y = data.loc[(data['localization'] == 'Periplasmic'),'50M_5mM_resin_weightedRPM']

memanchor_x = data.loc[(data['localization'] == 'Membrane-anchored'),'5mM_EDC_10M_resin_RPM_center_weighted']
memanchor_y = data.loc[(data['localization'] == 'Membrane-anchored'),'50M_5mM_resin_weightedRPM']

memassoci_x = data.loc[(data['localization'] == 'Membraneassociated'),'5mM_EDC_10M_resin_RPM_center_weighted']
memassoci_y = data.loc[(data['localization'] == 'Membraneassociated'),'50M_5mM_resin_weightedRPM']

outermem_x = data.loc[(data['localization'] == 'OutermembraneProtein'),'5mM_EDC_10M_resin_RPM_center_weighted']
outermem_y = data.loc[(data['localization'] == 'OutermembraneProtein'),'50M_5mM_resin_weightedRPM']

outerlipo_x = data.loc[(data['localization'] == 'OutermembraneLipoprotein'),'5mM_EDC_10M_resin_RPM_center_weighted']
outerlipo_y = data.loc[(data['localization'] == 'OutermembraneLipoprotein'),'50M_5mM_resin_weightedRPM']

lipo_x = data.loc[(data['localization'] == 'Lipoprotein'),'5mM_EDC_10M_resin_RPM_center_weighted']
lipo_y = data.loc[(data['localization'] == 'Lipoprotein'),'50M_5mM_resin_weightedRPM']

extracel_x = data.loc[(data['localization'] == 'extracellular'),'5mM_EDC_10M_resin_RPM_center_weighted']
extracel_y = data.loc[(data['localization'] == 'extracellular'),'50M_5mM_resin_weightedRPM']

na_x = data.loc[(data['localization'] == '-'),'5mM_EDC_10M_resin_RPM_center_weighted']
na_y = data.loc[(data['localization'] == '-'),'50M_5mM_resin_weightedRPM']


# Make a plot with labeled axes, etc
fig, ax = plt.subplots(figsize=(15, 7.5))
ax.set_xlabel('5mM_EDC_10M_resin_RPM_center_weighted')
ax.set_ylabel('50M_5mM_resin_weightedRPM')

plt.xscale('log')
plt.yscale('log')

# Make nice y-limits
ax.set_ylim(1, 1000000)
ax.set_xlim(1, 1000000)
plt.gca().set_aspect('equal', adjustable='box')


# plot content
_ = ax.plot(integralmem_x, integralmem_y, marker='.', color=(1,0,0),linestyle='none', markersize=4)
_ = ax.plot(cyto_x, cyto_y, marker='.', color=(0,0,1),linestyle='none', markersize=4)
_ = ax.plot(peri_x, peri_y, marker='.', color=(0,0.6,0),linestyle='none', markersize=4)
_ = ax.plot(memanchor_x, memanchor_y, marker='.', color=(1,0,0),linestyle='none', markersize=4)
_ = ax.plot(memassoci_x, memassoci_y, marker='.', color=(1,0,0),linestyle='none', markersize=4)
_ = ax.plot(outermem_x, outermem_y, marker='.', color=(0,0.6,0),linestyle='none', markersize=4)
_ = ax.plot(outerlipo_x, outerlipo_y, marker='.', color=(0,0.6,0),linestyle='none', markersize=4)
#_ = ax.plot(lipo_x, lipo_y, marker='.', color=(1,1,1),linestyle='none')
#_ = ax.plot(extracel_x, extracel_y, marker='.', color=(1,1,1),linestyle='none')
#_ = ax.plot(na_x, na_y, marker='.', color=(1,1,1),linestyle='none')
#_ = ax.plot(markerline_x, markerline_x, marker='.', color=(0,0,0),linestyle='none')

#diagonal marker line
diagonal_x=[1, 1000000]
diagonal_y=[1, 1000000]

#boundary marker line
#bound_x=[i*1 for i in diagonal_x]
#bound_y=[i*1.5 for i in diagonal_y]

plt.plot(diagonal_x, diagonal_y, '-',linewidth=1, color=(0,0,0))
#plt.plot(bound_x, bound_y,linewidth=2,linestyle='--', color='#808080')
# Add a legend
plt.legend(('integralmembrane','cytosolic','periplasmic','membrane_anchor','membrane_associated','outermembrane','outerlipo','lipo','extracellular','NA'), loc='upper left');
#Add a title
plt.title('5mM_EDC_10M_vs_50M_resin_RPM_center_weighted', fontsize=20, loc='center')

#calculate pearson correlation coefficient
x = data.loc[:,'5mM_EDC_10M_resin_RPM_center_weighted']
y = data.loc[:,'50M_5mM_resin_weightedRPM']
print('pearson correlatin coefficient and p-value:')
print(sp.stats.pearsonr(x,y))

#plt.savefig('/Users/ShuaiWang/Desktop/Shan_Lab/Ribo_seq/Data_analysis/Shuai_Plot/SRP_RPM_enrichment.pdf')
# Out:
# pearson correlatin coefficient and p-value:
# (nan, 1.0)
# /Users/ShuaiWang/anaconda3/lib/python3.6/site-packages/matplotlib/scale.py:114: RuntimeWarning: invalid value encountered in less_equal
#   out[a <= 0] = -1000

# %%
import numpy as np

# Pandas, conventionally imported as pd
import pandas as pd

import scipy as sp
# Plotting modules and settings.
import matplotlib.pyplot as plt
import seaborn as sns
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728',
          '#9467bd', '#8c564b', '#e377c2', '#7f7f7f',
          '#bcbd22', '#17becf']
sns.set(style='whitegrid', palette=colors, rc={'axes.labelsize': 16})

# The following is specific Jupyter notebooks
# %matplotlib inline
# %config InlineBackend.figure_formats = {'png', 'retina'}


# Slice out x and y values
data = pd.read_csv('/Users/ShuaiWang/Desktop/Shan_Lab/Ribo_seq/compiled_data/center_weighted_RPM_050918.csv', comment='#')

integralmem_x = data.loc[(data['localization'] == 'IntegralMembraneProtein'),'5mM_EDC_10M_input_RPM_center_weighted']
integralmem_y = data.loc[(data['localization'] == 'IntegralMembraneProtein'),'50M_5mM_input_weightedRPM']

cyto_x = data.loc[(data['localization'] == 'Cytoplasmic'),'5mM_EDC_10M_input_RPM_center_weighted']
cyto_y = data.loc[(data['localization'] == 'Cytoplasmic'),'50M_5mM_input_weightedRPM']

peri_x = data.loc[(data['localization'] == 'Periplasmic'),'5mM_EDC_10M_input_RPM_center_weighted']
peri_y = data.loc[(data['localization'] == 'Periplasmic'),'50M_5mM_input_weightedRPM']

memanchor_x = data.loc[(data['localization'] == 'Membrane-anchored'),'5mM_EDC_10M_input_RPM_center_weighted']
memanchor_y = data.loc[(data['localization'] == 'Membrane-anchored'),'50M_5mM_input_weightedRPM']

memassoci_x = data.loc[(data['localization'] == 'Membraneassociated'),'5mM_EDC_10M_input_RPM_center_weighted']
memassoci_y = data.loc[(data['localization'] == 'Membraneassociated'),'50M_5mM_input_weightedRPM']

outermem_x = data.loc[(data['localization'] == 'OutermembraneProtein'),'5mM_EDC_10M_input_RPM_center_weighted']
outermem_y = data.loc[(data['localization'] == 'OutermembraneProtein'),'50M_5mM_input_weightedRPM']

outerlipo_x = data.loc[(data['localization'] == 'OutermembraneLipoprotein'),'5mM_EDC_10M_input_RPM_center_weighted']
outerlipo_y = data.loc[(data['localization'] == 'OutermembraneLipoprotein'),'50M_5mM_input_weightedRPM']

lipo_x = data.loc[(data['localization'] == 'Lipoprotein'),'5mM_EDC_10M_input_RPM_center_weighted']
lipo_y = data.loc[(data['localization'] == 'Lipoprotein'),'50M_5mM_input_weightedRPM']

extracel_x = data.loc[(data['localization'] == 'extracellular'),'5mM_EDC_10M_input_RPM_center_weighted']
extracel_y = data.loc[(data['localization'] == 'extracellular'),'50M_5mM_input_weightedRPM']

na_x = data.loc[(data['localization'] == '-'),'5mM_EDC_10M_input_RPM_center_weighted']
na_y = data.loc[(data['localization'] == '-'),'50M_5mM_input_weightedRPM']


# Make a plot with labeled axes, etc
fig, ax = plt.subplots(figsize=(15, 7.5))
ax.set_xlabel('5mM_EDC_10M_input_RPM_center_weighted')
ax.set_ylabel('50M_5mM_input_weightedRPM')

plt.xscale('log')
plt.yscale('log')

# Make nice y-limits
ax.set_ylim(1, 1000000)
ax.set_xlim(1, 1000000)
plt.gca().set_aspect('equal', adjustable='box')


# plot content
_ = ax.plot(integralmem_x, integralmem_y, marker='.', color=(1,0,0),linestyle='none', markersize=4)
_ = ax.plot(cyto_x, cyto_y, marker='.', color=(0,0,1),linestyle='none', markersize=4)
_ = ax.plot(peri_x, peri_y, marker='.', color=(0,0.6,0),linestyle='none', markersize=4)
_ = ax.plot(memanchor_x, memanchor_y, marker='.', color=(1,0,0),linestyle='none', markersize=4)
_ = ax.plot(memassoci_x, memassoci_y, marker='.', color=(1,0,0),linestyle='none', markersize=4)
_ = ax.plot(outermem_x, outermem_y, marker='.', color=(0,0.6,0),linestyle='none', markersize=4)
_ = ax.plot(outerlipo_x, outerlipo_y, marker='.', color=(0,0.6,0),linestyle='none', markersize=4)
#_ = ax.plot(lipo_x, lipo_y, marker='.', color=(1,1,1),linestyle='none')
#_ = ax.plot(extracel_x, extracel_y, marker='.', color=(1,1,1),linestyle='none')
#_ = ax.plot(na_x, na_y, marker='.', color=(1,1,1),linestyle='none')
#_ = ax.plot(markerline_x, markerline_x, marker='.', color=(0,0,0),linestyle='none')

#diagonal marker line
diagonal_x=[1, 1000000]
diagonal_y=[1, 1000000]

#boundary marker line
#bound_x=[i*1 for i in diagonal_x]
#bound_y=[i*1.5 for i in diagonal_y]

plt.plot(diagonal_x, diagonal_y, '-',linewidth=1, color=(0,0,0))
#plt.plot(bound_x, bound_y,linewidth=2,linestyle='--', color='#808080')
# Add a legend
plt.legend(('integralmembrane','cytosolic','periplasmic','membrane_anchor','membrane_associated','outermembrane','outerlipo','lipo','extracellular','NA'), loc='upper left');
#Add a title
plt.title('5mM_EDC_10M_vs_50M_input_RPM_center_weighted', fontsize=20, loc='center')

#calculate pearson correlation coefficient
x = data.loc[:,'5mM_EDC_10M_input_RPM_center_weighted']
y = data.loc[:,'50M_5mM_input_weightedRPM']
print('pearson correlatin coefficient and p-value:')
print(sp.stats.pearsonr(x,y))

#plt.savefig('/Users/ShuaiWang/Desktop/Shan_Lab/Ribo_seq/Data_analysis/Shuai_Plot/SRP_RPM_enrichment.pdf')
# Out:
# pearson correlatin coefficient and p-value:
# (nan, 1.0)
# /Users/ShuaiWang/anaconda3/lib/python3.6/site-packages/matplotlib/scale.py:114: RuntimeWarning: invalid value encountered in less_equal
#   out[a <= 0] = -1000
