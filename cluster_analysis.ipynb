# %%
import numpy as np

# Pandas, conventionally imported as pd
import pandas as pd

import scipy as sp
# Plotting modules and settings.
import matplotlib.pyplot as plt
import seaborn as sns
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728',
          '#9467bd', '#8c564b', '#e377c2', '#7f7f7f',
          '#bcbd22', '#17becf']
sns.set(style='whitegrid', palette=colors, rc={'axes.labelsize': 16})

# The following is specific Jupyter notebooks
# %matplotlib inline
# %config InlineBackend.figure_formats = {'png', 'retina'}


# Slice out x and y values
data = pd.read_csv('/Users/ShuaiWang/Desktop/Shan_Lab/Ribo_seq/Data_analysis/SecA_enrichment_BrianRPM.csv', comment='#')

integralmem_x = data.loc[(data['localization'] == 'IntegralMembraneProtein'),'SRPenrichment_RPM']
integralmem_y = data.loc[(data['localization'] == 'IntegralMembraneProtein'),'5mM_EDC enrich']

cyto_x = data.loc[(data['localization'] == 'Cytoplasmic'),'SRPenrichment_RPM']
cyto_y = data.loc[(data['localization'] == 'Cytoplasmic'),'5mM_EDC enrich']

peri_x = data.loc[(data['localization'] == 'Periplasmic'),'SRPenrichment_RPM']
peri_y = data.loc[(data['localization'] == 'Periplasmic'),'5mM_EDC enrich']

memanchor_x = data.loc[(data['localization'] == 'Membrane-anchored'),'SRPenrichment_RPM']
memanchor_y = data.loc[(data['localization'] == 'Membrane-anchored'),'5mM_EDC enrich']

memassoci_x = data.loc[(data['localization'] == 'Membraneassociated'),'SRPenrichment_RPM']
memassoci_y = data.loc[(data['localization'] == 'Membraneassociated'),'5mM_EDC enrich']

outermem_x = data.loc[(data['localization'] == 'OutermembraneProtein'),'SRPenrichment_RPM']
outermem_y = data.loc[(data['localization'] == 'OutermembraneProtein'),'5mM_EDC enrich']

outerlipo_x = data.loc[(data['localization'] == 'OutermembraneLipoprotein'),'SRPenrichment_RPM']
outerlipo_y = data.loc[(data['localization'] == 'OutermembraneLipoprotein'),'5mM_EDC enrich']

lipo_x = data.loc[(data['localization'] == 'Lipoprotein'),'SRPenrichment_RPM']
lipo_y = data.loc[(data['localization'] == 'Lipoprotein'),'5mM_EDC enrich']

extracel_x = data.loc[(data['localization'] == 'extracellular'),'SRPenrichment_RPM']
extracel_y = data.loc[(data['localization'] == 'extracellular'),'5mM_EDC enrich']

na_x = data.loc[(data['localization'] == '-'),'SRPenrichment_RPM']
na_y = data.loc[(data['localization'] == '-'),'5mM_EDC enrich']


# Make a plot with labeled axes, etc
fig, ax = plt.subplots(figsize=(15, 10))
ax.set_xlabel('SRPenrichment_RPM')
ax.set_ylabel('5mM_EDC_SecAenrich')

#plt.xscale('log')
#plt.yscale('linear')

# Make nice y-limits
ax.set_ylim(0, 8)
ax.set_xlim(0, 40)
plt.gca().set_aspect('equal', adjustable='box')


# plot content
_ = ax.plot(integralmem_x, integralmem_y, marker='.', color=(1,0,0),linestyle='none', markersize=6)
_ = ax.plot(cyto_x, cyto_y, marker='.', color=(0,0,1),linestyle='none', markersize=6)
_ = ax.plot(peri_x, peri_y, marker='.', color=(0,0.6,0),linestyle='none', markersize=6)
_ = ax.plot(memanchor_x, memanchor_y, marker='.', color=(1,0,0),linestyle='none', markersize=6)
_ = ax.plot(memassoci_x, memassoci_y, marker='.', color=(1,0,0),linestyle='none', markersize=6)
_ = ax.plot(outermem_x, outermem_y, marker='.', color=(0,0.6,0),linestyle='none', markersize=6)
_ = ax.plot(outerlipo_x, outerlipo_y, marker='.', color=(0,0.6,0),linestyle='none', markersize=6)
#_ = ax.plot(lipo_x, lipo_y, marker='.', color=(1,1,1),linestyle='none')
#_ = ax.plot(extracel_x, extracel_y, marker='.', color=(1,1,1),linestyle='none')
#_ = ax.plot(na_x, na_y, marker='.', color=(1,1,1),linestyle='none')
#_ = ax.plot(markerline_x, markerline_x, marker='.', color=(0,0,0),linestyle='none')
#plt.plot([0, 40], [0, 6], '-',linewidth=1, color=(0,0,0))
# Add a legend
plt.legend(('integralmembrane','cytosolic','periplasmic','membrane_anchor','membrane_associated','outermembrane','outerlipo','lipo','extracellular','NA'), loc='upper right');
#Add a title
plt.title('SRP_VS_SecA', fontsize=20, loc='center')

#calculate pearson correlation coefficient
x = data.loc[:,'SRPenrichment_RPM']
y = data.loc[:,'5mM_EDC enrich']
print('pearson correlatin coefficient and p-value:')
print(sp.stats.pearsonr(x,y))

plt.savefig('/Users/ShuaiWang/Desktop/Shan_Lab/Ribo_seq/Data_analysis/Shuai_Plot/SRP_vs_SecA_5mMEDC_10M.pdf')
# Out:
# pearson correlatin coefficient and p-value:
# (0.2677366180025882, 5.790702737795336e-38)

# %%
import numpy as np

# Pandas, conventionally imported as pd
import pandas as pd

import scipy as sp
# Plotting modules and settings.
import matplotlib.pyplot as plt
import seaborn as sns
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728',
          '#9467bd', '#8c564b', '#e377c2', '#7f7f7f',
          '#bcbd22', '#17becf']
sns.set(style='whitegrid', palette=colors, rc={'axes.labelsize': 16})

# The following is specific Jupyter notebooks
# %matplotlib inline
# %config InlineBackend.figure_formats = {'png', 'retina'}


# Slice out x and y values
data = pd.read_csv('/Users/ShuaiWang/Desktop/Shan_Lab/Ribo_seq/Data_analysis/SecA_enrichment_BrianRPM.csv', comment='#')

integralmem_x = data.loc[(data['localization'] == 'IntegralMembraneProtein'),'SRPenrichment_RPM_log2']
integralmem_y = data.loc[(data['localization'] == 'IntegralMembraneProtein'),'60M_5mM_EDC_enrichment_log2']

cyto_x = data.loc[(data['localization'] == 'Cytoplasmic'),'SRPenrichment_RPM_log2']
cyto_y = data.loc[(data['localization'] == 'Cytoplasmic'),'60M_5mM_EDC_enrichment_log2']

peri_x = data.loc[(data['localization'] == 'Periplasmic'),'SRPenrichment_RPM_log2']
peri_y = data.loc[(data['localization'] == 'Periplasmic'),'60M_5mM_EDC_enrichment_log2']

memanchor_x = data.loc[(data['localization'] == 'Membrane-anchored'),'SRPenrichment_RPM_log2']
memanchor_y = data.loc[(data['localization'] == 'Membrane-anchored'),'60M_5mM_EDC_enrichment_log2']

memassoci_x = data.loc[(data['localization'] == 'Membraneassociated'),'SRPenrichment_RPM_log2']
memassoci_y = data.loc[(data['localization'] == 'Membraneassociated'),'60M_5mM_EDC_enrichment_log2']

outermem_x = data.loc[(data['localization'] == 'OutermembraneProtein'),'SRPenrichment_RPM_log2']
outermem_y = data.loc[(data['localization'] == 'OutermembraneProtein'),'60M_5mM_EDC_enrichment_log2']

outerlipo_x = data.loc[(data['localization'] == 'OutermembraneLipoprotein'),'SRPenrichment_RPM_log2']
outerlipo_y = data.loc[(data['localization'] == 'OutermembraneLipoprotein'),'60M_5mM_EDC_enrichment_log2']

lipo_x = data.loc[(data['localization'] == 'Lipoprotein'),'SRPenrichment_RPM_log2']
lipo_y = data.loc[(data['localization'] == 'Lipoprotein'),'60M_5mM_EDC_enrichment_log2']

extracel_x = data.loc[(data['localization'] == 'extracellular'),'SRPenrichment_RPM_log2']
extracel_y = data.loc[(data['localization'] == 'extracellular'),'60M_5mM_EDC_enrichment_log2']

na_x = data.loc[(data['localization'] == '-'),'SRPenrichment_RPM_log2']
na_y = data.loc[(data['localization'] == '-'),'60M_5mM_EDC_enrichment_log2']


# Make a plot with labeled axes, etc
fig, ax = plt.subplots(figsize=(15, 10))
ax.set_xlabel('SRPenrichment_RPM_log2')
ax.set_ylabel('SecA_60M_5mM_EDC_enrichment_log2')

#plt.xscale('log')
#plt.yscale('linear')

# Make nice y-limits
ax.set_ylim(-3, 4)
ax.set_xlim(-2, 6)
plt.gca().set_aspect('equal', adjustable='box')

# plot content
_ = ax.plot(integralmem_x, integralmem_y, marker='.', color=(1,0,0),linestyle='none', markersize=10)
_ = ax.plot(cyto_x, cyto_y, marker='.', color=(0,0,1),linestyle='none', markersize=10)
_ = ax.plot(peri_x, peri_y, marker='.', color=(0,0.6,0),linestyle='none', markersize=10)
_ = ax.plot(memanchor_x, memanchor_y, marker='.', color=(1,0,0),linestyle='none', markersize=10)
_ = ax.plot(memassoci_x, memassoci_y, marker='.', color=(1,0,0),linestyle='none', markersize=10)
_ = ax.plot(outermem_x, outermem_y, marker='.', color=(0,0.6,0),linestyle='none', markersize=10)
_ = ax.plot(outerlipo_x, outerlipo_y, marker='.', color=(0,0.6,0),linestyle='none', markersize=10)
#_ = ax.plot(lipo_x, lipo_y, marker='.', color=(1,1,1),linestyle='none')
#_ = ax.plot(extracel_x, extracel_y, marker='.', color=(1,1,1),linestyle='none')
#_ = ax.plot(na_x, na_y, marker='.', color=(1,1,1),linestyle='none')
#_ = ax.plot(markerline_x, markerline_x, marker='.', color=(0,0,0),linestyle='none')
#plt.plot([0, 40], [0, 6], '-',linewidth=1, color=(0,0,0))
# Add a legend
plt.legend(('integralmembrane','cytosolic','periplasmic','membrane_anchor','membrane_associated','outermembrane','outerlipo','lipo','extracellular','NA'), loc='upper right');
#Add a title
plt.title('SRP_VS_SecA_60M', fontsize=20, loc='center')

#calculate pearson correlation coefficient
x = data.loc[:,'SRPenrichment_RPM_log2']
y = data.loc[:,'60M_5mM_EDC_enrichment_log2']
print('pearson correlatin coefficient and p-value:')
print(sp.stats.pearsonr(x,y))

plt.savefig('/Users/ShuaiWang/Desktop/Shan_Lab/Ribo_seq/Data_analysis/Shuai_Plot/SRP_vs_SecA_5mMEDC_60M.pdf')
# Out:
# pearson correlatin coefficient and p-value:
# (0.5052948740330452, 5.056239638630129e-145)

# %%
import numpy as np

# Pandas, conventionally imported as pd
import pandas as pd

import scipy as sp
# Plotting modules and settings.
import matplotlib.pyplot as plt
import seaborn as sns
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728',
          '#9467bd', '#8c564b', '#e377c2', '#7f7f7f',
          '#bcbd22', '#17becf']
sns.set(style='whitegrid', palette=colors, rc={'axes.labelsize': 16})

# The following is specific Jupyter notebooks
# %matplotlib inline
# %config InlineBackend.figure_formats = {'png', 'retina'}


# Slice out x and y values
data = pd.read_csv('/Users/ShuaiWang/Desktop/Shan_Lab/Ribo_seq/03172018/input_5mM/10M/center_weighted_RPM_10M_Bukaulocal.csv', comment='#')

integralmem_x = data.loc[(data['localization'] == 'IntegralMembraneProtein'),'ratio RPM']
integralmem_y = data.loc[(data['localization'] == 'IntegralMembraneProtein'),'enrichment_RPM_weighted']

cyto_x = data.loc[(data['localization'] == 'Cytoplasmic'),'ratio RPM']
cyto_y = data.loc[(data['localization'] == 'Cytoplasmic'),'enrichment_RPM_weighted']

peri_x = data.loc[(data['localization'] == 'Periplasmic'),'ratio RPM']
peri_y = data.loc[(data['localization'] == 'Periplasmic'),'enrichment_RPM_weighted']

memanchor_x = data.loc[(data['localization'] == 'Membrane-anchored'),'ratio RPM']
memanchor_y = data.loc[(data['localization'] == 'Membrane-anchored'),'enrichment_RPM_weighted']

memassoci_x = data.loc[(data['localization'] == 'Membraneassociated'),'ratio RPM']
memassoci_y = data.loc[(data['localization'] == 'Membraneassociated'),'enrichment_RPM_weighted']

outermem_x = data.loc[(data['localization'] == 'OutermembraneProtein'),'ratio RPM']
outermem_y = data.loc[(data['localization'] == 'OutermembraneProtein'),'enrichment_RPM_weighted']

outerlipo_x = data.loc[(data['localization'] == 'OutermembraneLipoprotein'),'ratio RPM']
outerlipo_y = data.loc[(data['localization'] == 'OutermembraneLipoprotein'),'enrichment_RPM_weighted']

lipo_x = data.loc[(data['localization'] == 'Lipoprotein'),'ratio RPM']
lipo_y = data.loc[(data['localization'] == 'Lipoprotein'),'enrichment_RPM_weighted']

extracel_x = data.loc[(data['localization'] == 'extracellular'),'ratio RPM']
extracel_y = data.loc[(data['localization'] == 'extracellular'),'enrichment_RPM_weighted']

na_x = data.loc[(data['localization'] == '-'),'ratio RPM']
na_y = data.loc[(data['localization'] == '-'),'enrichment_RPM_weighted']


# Make a plot with labeled axes, etc
fig, ax = plt.subplots(figsize=(15, 10))
ax.set_xlabel('ratio RPM_SecA')
ax.set_ylabel('enrichment_RPM_weighted_secA')

#plt.xscale('log')
#plt.yscale('linear')

# Make nice y-limits
#ax.set_ylim(-3, 4)
#ax.set_xlim(-2, 6)
plt.gca().set_aspect('equal', adjustable='box')

# plot content
_ = ax.plot(integralmem_x, integralmem_y, marker='.', color=(1,0,0),linestyle='none', markersize=10)
_ = ax.plot(cyto_x, cyto_y, marker='.', color=(0,0,1),linestyle='none', markersize=10)
_ = ax.plot(peri_x, peri_y, marker='.', color=(0,0.6,0),linestyle='none', markersize=10)
_ = ax.plot(memanchor_x, memanchor_y, marker='.', color=(1,0,0),linestyle='none', markersize=10)
_ = ax.plot(memassoci_x, memassoci_y, marker='.', color=(1,0,0),linestyle='none', markersize=10)
_ = ax.plot(outermem_x, outermem_y, marker='.', color=(0,0.6,0),linestyle='none', markersize=10)
_ = ax.plot(outerlipo_x, outerlipo_y, marker='.', color=(0,0.6,0),linestyle='none', markersize=10)
#_ = ax.plot(lipo_x, lipo_y, marker='.', color=(1,1,1),linestyle='none')
#_ = ax.plot(extracel_x, extracel_y, marker='.', color=(1,1,1),linestyle='none')
#_ = ax.plot(na_x, na_y, marker='.', color=(1,1,1),linestyle='none')
#_ = ax.plot(markerline_x, markerline_x, marker='.', color=(0,0,0),linestyle='none')
#plt.plot([0, 40], [0, 6], '-',linewidth=1, color=(0,0,0))
# Add a legend
plt.legend(('integralmembrane','cytosolic','periplasmic','membrane_anchor','membrane_associated','outermembrane','outerlipo','lipo','extracellular','NA'), loc='upper right');
#Add a title
plt.title('SRP_VS_SecA_60M', fontsize=20, loc='center')

#calculate pearson correlation coefficient
#x = data.loc[:,'SRPenrichment_RPM_log2']
#y = data.loc[:,'60M_5mM_EDC_enrichment_log2']
#print('pearson correlatin coefficient and p-value:')
#print(sp.stats.pearsonr(x,y))

plt.savefig('/Users/ShuaiWang/Desktop/Shan_Lab/Ribo_seq/Data_analysis/Shuai_Plot/SRP_vs_SecA_5mMEDC_60M.pdf')
